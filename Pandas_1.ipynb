# %%
import pandas as pd
import numpy as np

# %%
sample = {
    'names' : ['Ram','Shayam','Sita','Rahul','Om'],
    'age' : [13,56,34,88,32],
    'gender' : ['Male','Male','Female','Male','Male']
}

pd.DataFrame(sample)
# Out:
#     names  age  gender
# 0     Ram   13    Male
# 1  Shayam   56    Male
# 2    Sita   34  Female
# 3   Rahul   88    Male
# 4      Om   32    Male

# %%
pd.DataFrame(data=sample,index=['R1','R2','R3','R4','R5'])
# Out:
#      names  age  gender
# R1     Ram   13    Male
# R2  Shayam   56    Male
# R3    Sita   34  Female
# R4   Rahul   88    Male
# R5      Om   32    Male

# %%
# ---------------------------------------------

# %%
arr = np.arange(0,40).reshape(10, 4)

# %%
## Create Dataframe
df=pd.DataFrame(data=arr,index=["Row1","Row2","Row3","Row4","Row5","Row6","Row7","Row8","Row9","Row10"],
                columns=["Column1","Column2","Column3","Column4"])

# %%
df.head(3)
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11

# %%
df.tail(4)
# Out:
#        Column1  Column2  Column3  Column4
# Row7        24       25       26       27
# Row8        28       29       30       31
# Row9        32       33       34       35
# Row10       36       37       38       39

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Row1 to Row10
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  10 non-null     int64
#  1   Column2  10 non-null     int64
#  2   Column3  10 non-null     int64
#  3   Column4  10 non-null     int64
# dtypes: int64(4)
# memory usage: 400.0+ bytes

# %%
df.describe()
# Out:
#          Column1    Column2    Column3    Column4
# count  10.000000  10.000000  10.000000  10.000000
# mean   18.000000  19.000000  20.000000  21.000000
# std    12.110601  12.110601  12.110601  12.110601
# min     0.000000   1.000000   2.000000   3.000000
# 25%     9.000000  10.000000  11.000000  12.000000
# 50%    18.000000  19.000000  20.000000  21.000000
# 75%    27.000000  28.000000  29.000000  30.000000
# max    36.000000  37.000000  38.000000  39.000000

# %% [markdown]
# **Indexing in Pandas**

# %%
# Using column name
df['Column1']
# Out:
# Row1      0
# Row2      4
# Row3      8
# Row4     12
# Row5     16
# Row6     20
# Row7     24
# Row8     28
# Row9     32
# Row10    36
# Name: Column1, dtype: int64

# %%
type(df['Column1'])
# Out:
# pandas.core.series.Series

# %%
df[['Column1','Column2']]
# Out:
#        Column1  Column2
# Row1         0        1
# Row2         4        5
# Row3         8        9
# Row4        12       13
# Row5        16       17
# Row6        20       21
# Row7        24       25
# Row8        28       29
# Row9        32       33
# Row10       36       37

# %%
type(df[['Column1','Column2']])
# Out:
# pandas.core.frame.DataFrame

# %%
# using row index name
df.loc[['Row2','Row3','Row6']]
# Out:
#       Column1  Column2  Column3  Column4
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row6       20       21       22       23

# %%
# using row and column index number
df.iloc[3:6,:3]
# Out:
#       Column1  Column2  Column3
# Row4       12       13       14
# Row5       16       17       18
# Row6       20       21       22

# %%
df.iloc[:,::3]
# Out:
#        Column1  Column4
# Row1         0        3
# Row2         4        7
# Row3         8       11
# Row4        12       15
# Row5        16       19
# Row6        20       23
# Row7        24       27
# Row8        28       31
# Row9        32       35
# Row10       36       39

# %%
# convert dataframe to array
df.iloc[3:6,:3].values
# Out:
# array([[12, 13, 14],
#        [16, 17, 18],
#        [20, 21, 22]])

# %%
df
# Out:
#        Column1  Column2  Column3  Column4
# Row1         0        1        2        3
# Row2         4        5        6        7
# Row3         8        9       10       11
# Row4        12       13       14       15
# Row5        16       17       18       19
# Row6        20       21       22       23
# Row7        24       25       26       27
# Row8        28       29       30       31
# Row9        32       33       34       35
# Row10       36       37       38       39

# %%
df.iloc[3, 2] = np.nan
df.iloc[6, 0] = np.nan
df.iloc[8, 2] = np.nan
df.iloc[6, 3] = np.nan
df.iloc[4, 1] = np.nan

# %%
df
# Out:
#        Column1  Column2  Column3  Column4
# Row1       0.0      1.0      2.0      3.0
# Row2       4.0      5.0      6.0      7.0
# Row3       8.0      9.0     10.0     11.0
# Row4      12.0     13.0      NaN     15.0
# Row5      16.0      NaN     18.0     19.0
# Row6      20.0     21.0     22.0     23.0
# Row7       NaN     25.0     26.0      NaN
# Row8      28.0     29.0     30.0     31.0
# Row9      32.0     33.0      NaN     35.0
# Row10     36.0     37.0     38.0     39.0

# %%
df.isnull()
# Out:
#        Column1  Column2  Column3  Column4
# Row1     False    False    False    False
# Row2     False    False    False    False
# Row3     False    False    False    False
# Row4     False    False     True    False
# Row5     False     True    False    False
# Row6     False    False    False    False
# Row7      True    False    False     True
# Row8     False    False    False    False
# Row9     False    False     True    False
# Row10    False    False    False    False

# %%
df.isnull().sum()
# Out:
# Column1    1
# Column2    1
# Column3    2
# Column4    1
# dtype: int64

# %%
df['Column3'].value_counts()
# Out:
# Column3
# 2.0     1
# 6.0     1
# 10.0    1
# 18.0    1
# 22.0    1
# 26.0    1
# 30.0    1
# 38.0    1
# Name: count, dtype: int64

# %%
df['Column3'].unique()
# Out:
# array([ 2.,  6., 10., nan, 18., 22., 26., 30., 38.])

# %%
# conditional indexing
df[df['Column2']>5]
# Out:
#        Column1  Column2  Column3  Column4
# Row3       8.0      9.0     10.0     11.0
# Row4      12.0     13.0      NaN     15.0
# Row6      20.0     21.0     22.0     23.0
# Row7       NaN     25.0     26.0      NaN
# Row8      28.0     29.0     30.0     31.0
# Row9      32.0     33.0      NaN     35.0
# Row10     36.0     37.0     38.0     39.0

# %%
# conditional indexing
df[(df['Column2']>5) & (df['Column3']>10)]
# Out:
#        Column1  Column2  Column3  Column4
# Row6      20.0     21.0     22.0     23.0
# Row7       NaN     25.0     26.0      NaN
# Row8      28.0     29.0     30.0     31.0
# Row10     36.0     37.0     38.0     39.0

# %%
# conditional querying
result = df.query("Column2 > 5 and Column3 > 10")
result
# Out:
#        Column1  Column2  Column3  Column4
# Row6      20.0     21.0     22.0     23.0
# Row7       NaN     25.0     26.0      NaN
# Row8      28.0     29.0     30.0     31.0
# Row10     36.0     37.0     38.0     39.0
